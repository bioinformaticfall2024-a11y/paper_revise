# %% [markdown]
# # Reviewer 3 — Comment 17
# ## pKd conversion verification
#
# For Kd supplied in nanomolar, the unit-aware conversion is `pKd = -log10(Kd_nM / 1e9) = 9 - log10(Kd_nM)`.

# %%
import math
for kd in [0.1,1,10,100,1000,10000]:
    print(f"Kd={kd:g} nM -> pKd={-math.log10(kd/1e9):.4f}")
print('pKd = -log10(Kd_nM / 1e9) = 9 - log10(Kd_nM)')
# Out:
# Kd=0.1 nM -> pKd=10.0000
# Kd=1 nM -> pKd=9.0000
# Kd=10 nM -> pKd=8.0000
# Kd=100 nM -> pKd=7.0000
# Kd=1000 nM -> pKd=6.0000
# Kd=10000 nM -> pKd=5.0000
# pKd = -log10(Kd_nM / 1e9) = 9 - log10(Kd_nM)
