# %% [markdown]
# # Reviewer 3 — Comment 14: repeated runs and uncertainty
#
# Template for aggregating five-seed results and computing mean/SD after seed-level results are available.
#
# > **Status:** prepared but the final experiment is NOT run here because exact training/data assets are required. No reviewer-facing performance number should be claimed until rerun with those assets.

# %%
# Expected CSV columns: seed, model, dataset, MSE, CI, Pearson
import pandas as pd
# df = pd.read_csv('seed_results.csv')
# summary = df.groupby(['model','dataset'])[['MSE','CI','Pearson']].agg(['mean','std','count'])
# display(summary)
