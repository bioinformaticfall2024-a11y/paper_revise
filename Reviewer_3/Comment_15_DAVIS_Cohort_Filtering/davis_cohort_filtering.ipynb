# %% [markdown]
# # Reviewer 3 — Comment 15: DAVIS cohort/filtering audit
#
# Template for tracing accepted/rejected proteins and interaction counts through the contact-map pipeline.
#
# > **Status:** prepared but the final experiment is NOT run here because exact training/data assets are required. No reviewer-facing performance number should be claimed until rerun with those assets.

# %%
# Required: original DAVIS protein list, contact-map success/failure log, exact split indices.
from collections import Counter
# rejection_reasons = Counter(...)
# print(rejection_reasons)
