# %% [markdown]
# # Reviewer 3 — Comment 19: PVgraphDTA cold-target run
#
# Template for running PVgraphDTA on the exact protein-disjoint split used for the FGgraphDTA cold-target experiment.
#
# > **Status:** prepared but the final experiment is NOT run here because exact training/data assets are required. No reviewer-facing performance number should be claimed until rerun with those assets.

# %%
# Requires exact saved cold-target split + PVgraphDTA training entry point.
# Execute actual training and save per-target predictions; do not invent metrics.
